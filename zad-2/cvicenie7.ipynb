# %% [markdown]
# # Cvičenie č. 7

# %% [markdown]
# 1. Načítajte dáta, kódery a normalizéry prichystané na cvičení číslo 2.

# %% [markdown]
# 2. Využite modely založené na učení bez učiteľa (KMeans, DBSCAN) na zhlukovanie dát. Pozrite si dokumentáciu a zistite, aké parametre modelov viete meniť. Nezabudnite si nazvať modely rôzne, aby ste vedeli v ďalších bodoch vyhodnocovať oba modely samostatne.
#
# Linky:
#
#
# *   [KMeans](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)
# *   [DBSCAN](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html)

# %% [markdown]
# 3. Vypíšte:
#
#
# *   počet tried,
# *   počet záznamov v jednotlivých zhlukoch,
# *   pre náhodných 50 záznamov zhluk do ktorého patria.

# %% [markdown]
# 4. Redukujte dimenziu dát do 3D priestoru, využite:
#
#
# *   PCA,
# *   UMAP,
# *  t-SNE.
#
# Linky:
#
#
# *   [PCA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html)
# *   [UMAP](https://umap-learn.readthedocs.io/en/latest/basic_usage.html)
# *   [t-SNE](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html)

# %% [markdown]
# 5. Zobrazte náhodných 50 záznamov v 3D priestore. Body v grafe vyfarbite podľa prislúchajúceho zhluku, nezabudnite pridať aj legendu.
#
#
#
# *   [Príklad vizualizácie v 2D priestore](https://stackoverflow.com/questions/66204637/visualizing-clusters-result-using-pca-python)

# %% [markdown]
# 6. Skúste najskôr redukovať dimenziu (nemusíte do 3D, aby ste nestratili príliš veľa informácií - ak využijete PCA, môžete si vybrať počet dimenzií na základe zachovanej variance dát pre určitý počet dimenzií) a následne zhlukovanie dát. Po zhlukovaní zredukujte dimenziu ešte viac (do 3D) a pre 50 náhodných záznamov zobrazte body v 3D grafe.
#
# Linky:
#
#
# *   [Redukcia dimenzie + KMeans + zobrazenie v grafe](https://365datascience.com/tutorials/python-tutorials/pca-k-means/)
