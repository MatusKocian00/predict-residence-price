# %% [markdown]
# # Cvičenie č. 6

# %% [markdown]
# 1. Načítajte dáta, kódery a normalizéry prichistané na cvičení číslo 2.

# %% [markdown]
# 2. Pre obe úlohy z predošlého cvičenia (klasifikácia aj regresia) natrénujte modely založené na stromoch (strom, les). Tentokrát však meňte parametre modelov tak, aby ste sa vyhli pretrénovaniu. Porovnajte dosiahnuté výsledky modelov.

# %% [markdown]
# 3. Porovnajte dôležitosť príznakov (feature importance) pre les a jeden strom z lesa - pomôžte si dokumentáciou.

# %% [markdown]
# 4. Zobrazte jeden strom z lesa (myslite pri tom na to, že zmenou parametrov modelu viete ovplyvniť jeho veľkosť - príliš veľký strom sa vám bude vykresľovať pridlho, alebo sa nevykreslí vôbec).
#
# Linky:
#
#
# *   [Zobrazenie stromu](https://towardsdatascience.com/how-to-visualize-a-decision-tree-from-a-random-forest-in-python-using-scikit-learn-38ad2d75f21c)

# %% [markdown]
# 5. Pridajte do trénovania krížovú validáciu.
#
# Linky:
#
#
# *   [Krížová validácia](https://scikit-learn.org/stable/modules/cross_validation.html)
